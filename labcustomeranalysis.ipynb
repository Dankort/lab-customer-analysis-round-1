# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/danort/Desktop/Ironhack labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv")
df1.head()
df1.shape
df1.columns = df1.columns.str.upper().str.replace(' ', '_').str.replace('[^a-zA-Z0-9_]', '')
df1
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv("/Users/danort/Desktop/Ironhack labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv")
df2.head()
df2.shape
df2.columns = df2.columns.str.upper().str.replace(' ', '_').str.replace('[^a-zA-Z0-9_]', '')
df2
# Out:
#     CUSTOMER          ST GENDER EDUCATION CUSTOMER_LIFETIME_VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY_PREMIUM_AUTO NUMBER_OF_OPEN_COMPLAINTS  TOTAL_CLAIM_AMOUNT  \
# ...

# %%
df3 = pd.read_csv("/Users/danort/Desktop/Ironhack labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv")
df3.head()
df3.shape
df3.columns = df3.columns.str.upper().str.replace(' ', '_').str.replace('[^a-zA-Z0-9_]', '')

#changing the name of a column

df3 = df3.rename(columns={'STATE' : 'ST'})
df3
# Out:
#      CUSTOMER          ST  CUSTOMER_LIFETIME_VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY_PREMIUM_AUTO  NUMBER_OF_OPEN_COMPLAINTS  \
# ...

# %%
#Rearranging
df1 = df1[["CUSTOMER", "ST", "GENDER", "EDUCATION", "INCOME", "CUSTOMER_LIFETIME_VALUE", "NUMBER_OF_OPEN_COMPLAINTS", "VEHICLE_CLASS", "POLICY_TYPE", "MONTHLY_PREMIUM_AUTO", "TOTAL_CLAIM_AMOUNT"]]
df2 = df2[["CUSTOMER", "ST", "GENDER", "EDUCATION", "INCOME", "CUSTOMER_LIFETIME_VALUE", "NUMBER_OF_OPEN_COMPLAINTS", "VEHICLE_CLASS", "POLICY_TYPE", "MONTHLY_PREMIUM_AUTO", "TOTAL_CLAIM_AMOUNT"]]
df3 = df3[["CUSTOMER", "ST", "GENDER", "EDUCATION", "INCOME", "CUSTOMER_LIFETIME_VALUE", "NUMBER_OF_OPEN_COMPLAINTS", "VEHICLE_CLASS", "POLICY_TYPE", "MONTHLY_PREMIUM_AUTO", "TOTAL_CLAIM_AMOUNT"]]

display(df1)
display(df2)
display(df3)
# Out:
#      CUSTOMER          ST GENDER             EDUCATION   INCOME  \
# 0     RB50392  Washington    NaN                Master      0.0
# 1     QZ44356     Arizona      F              Bachelor      0.0
# 2     AI49188      Nevada      F              Bachelor  48767.0
# 3     WW63253  California      M              Bachelor      0.0
# 4     GA49547  Washington      M  High School or Below  36357.0
# ...       ...         ...    ...                   ...      ...
# 4003      NaN         NaN    NaN                   NaN      NaN
# 4004      NaN         NaN    NaN                   NaN      NaN
# 4005      NaN         NaN    NaN                   NaN      NaN
# 4006      NaN         NaN    NaN                   NaN      NaN
# 4007      NaN         NaN    NaN                   NaN      NaN
#
#      CUSTOMER_LIFETIME_VALUE NUMBER_OF_OPEN_COMPLAINTS  VEHICLE_CLASS  \
# 0                        NaN                    1/0/00  Four-Door Car
# ...

# %%
data = pd.concat([df1,df2,df3], axis=0).reset_index(drop=True)
data
# Out:
#       CUSTOMER          ST GENDER             EDUCATION   INCOME  \
# 0      RB50392  Washington    NaN                Master      0.0
# 1      QZ44356     Arizona      F              Bachelor      0.0
# 2      AI49188      Nevada      F              Bachelor  48767.0
# 3      WW63253  California      M              Bachelor      0.0
# 4      GA49547  Washington      M  High School or Below  36357.0
# ...        ...         ...    ...                   ...      ...
# 12069  LA72316  California      M              Bachelor  71941.0
# 12070  PK87824  California      F               College  21604.0
# 12071  TD14365  California      M              Bachelor      0.0
# 12072  UP19263  California      M               College  21941.0
# 12073  Y167826  California      M               College      0.0
#
#       CUSTOMER_LIFETIME_VALUE NUMBER_OF_OPEN_COMPLAINTS  VEHICLE_CLASS  \
# 0                         NaN                    1/0/00  Four-Door Car
# ...

# %%
#Which columns are numerical

numerical_columns = data.select_dtypes(include=['int', 'float']).columns
numerical_columns
# Out:
# Index(['INCOME', 'MONTHLY_PREMIUM_AUTO', 'TOTAL_CLAIM_AMOUNT'], dtype='object')

# %%
#Which columns are categorical
categorical_columns = data.select_dtypes(include=['category']).columns
categorical_columns
# Out:
# Index([], dtype='object')

# %%
#Delete the column education and the number of open complaints from the dataframe.

data.drop(['EDUCATION', 'NUMBER_OF_OPEN_COMPLAINTS'], axis=1, inplace=True)

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type

data['CUSTOMER_LIFETIME_VALUE'] = data['CUSTOMER_LIFETIME_VALUE'].astype(str).str.rstrip('%').astype('float')*100.0
data
# Out:
#       CUSTOMER          ST GENDER   INCOME  CUSTOMER_LIFETIME_VALUE  \
# 0      RB50392  Washington    NaN      0.0                      NaN
# 1      QZ44356     Arizona      F      0.0               69795359.0
# 2      AI49188      Nevada      F  48767.0              128874317.0
# 3      WW63253  California      M      0.0               76458618.0
# 4      GA49547  Washington      M  36357.0               53630765.0
# ...        ...         ...    ...      ...                      ...
# 12069  LA72316  California      M  71941.0                      NaN
# 12070  PK87824  California      F  21604.0                      NaN
# 12071  TD14365  California      M      0.0                      NaN
# 12072  UP19263  California      M  21941.0                      NaN
# 12073  Y167826  California      M      0.0                      NaN
#
#        VEHICLE_CLASS     POLICY_TYPE  MONTHLY_PREMIUM_AUTO  TOTAL_CLAIM_AMOUNT
# ...

# %%
#Check for duplicate rows in the data and remove if any.

data

duplicate_rows = data[data.duplicated()]
duplicate_rows
# Out:
#      CUSTOMER          ST GENDER   INCOME  CUSTOMER_LIFETIME_VALUE  \
# 1072      NaN         NaN    NaN      NaN                      NaN
# 1073      NaN         NaN    NaN      NaN                      NaN
# 1074      NaN         NaN    NaN      NaN                      NaN
# 1075      NaN         NaN    NaN      NaN                      NaN
# 1076      NaN         NaN    NaN      NaN                      NaN
# ...       ...         ...    ...      ...                      ...
# 4010  MY31220  California      F  54230.0               89970402.0
# 6002  TO60700  Washington      F  25859.0                      NaN
# 6475  RI52095  Washington      M  51878.0                      NaN
# 6491  MW80236  Washington      M      0.0                      NaN
# 6539  SP81997  Washington      F  41275.0                      NaN
#
#       VEHICLE_CLASS    POLICY_TYPE  MONTHLY_PREMIUM_AUTO  TOTAL_CLAIM_AMOUNT
# 1072            NaN            NaN                   NaN                 NaN
# ...

# %%
#Remove duplicate

data.drop_duplicates(inplace=True)
data
# Out:
#       CUSTOMER          ST GENDER   INCOME  CUSTOMER_LIFETIME_VALUE  \
# 0      RB50392  Washington    NaN      0.0                      NaN
# 1      QZ44356     Arizona      F      0.0               69795359.0
# 2      AI49188      Nevada      F  48767.0              128874317.0
# 3      WW63253  California      M      0.0               76458618.0
# 4      GA49547  Washington      M  36357.0               53630765.0
# ...        ...         ...    ...      ...                      ...
# 12069  LA72316  California      M  71941.0                      NaN
# 12070  PK87824  California      F  21604.0                      NaN
# 12071  TD14365  California      M      0.0                      NaN
# 12072  UP19263  California      M  21941.0                      NaN
# 12073  Y167826  California      M      0.0                      NaN
#
#        VEHICLE_CLASS     POLICY_TYPE  MONTHLY_PREMIUM_AUTO  TOTAL_CLAIM_AMOUNT
# ...
